# %% [markdown]
# INDIAN ARMY HIGH SECURITY COMMUNICATION SYSTEM PROTECTION THROUGH CRYPTOGRAPHY

# %% [markdown]
# Triple DES Project for Image ECRYPTION & DECRYPTION

# %% [markdown]
# # Load Libraries & Utilies

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import io
# !pip install pyDes
from pyDes import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Collecting pyDes
#   Downloading pyDes-2.0.1.tar.gz (9.9 kB)
# Building wheels for collected packages: pyDes
#   Building wheel for pyDes (setup.py) ... done
#   Created wheel for pyDes: filename=pyDes-2.0.1-py2.py3-none-any.whl size=9565 sha256=891bfdfb8c09fe02f36164d9a0e4e6ef70230d82ee6d0ef9e7e065a11fb9a9a7
#   Stored in directory: /root/.cache/pip/wheels/57/45/3a/cd3cffc8044aa6b8670109a57db784cc7c64dc52259a11575a
# Successfully built pyDes
# Installing collected packages: pyDes
# Successfully installed pyDes-2.0.1

# %% [markdown]
# # Define Functions

# %%
# Function to Display Image
def imgdis(path):
  """
  Function to display an image.
  Parameter : Path of image file
  """
  img = mpimg.imread(path)
  imgplot = plt.imshow(img)
  plt.show()

# %%
# Function to Encrypt an File with Triple DES
def encrypt(key, path, output = 'Encrypted'):
  """
  Function to Encrypt an File with Triple DES

  Parameters :  path, key, output;

  Key  : Takes a Key for the Encryption Process.
  Path : Takes Absolute or Relative Path of File as Input.
  Output : Takes Absolute or Relative Path of File as Output.

  Returns : An Encrypted File.
  """
  with open(path, 'rb') as file1:
    plaintext = file1.read()
    cipher_encrypt = triple_des(key, CBC, "\0\0\0\0\0\0\0\0", pad=None, padmode= PAD_PKCS5)
    ciphertext = cipher_encrypt.encrypt(plaintext)
    with open(output, 'wb') as file2:
      file2.write(ciphertext)
  print("Encryption Complete.")

# %%
# Function to Decrypt an File with Triple DES
def decrypt(key, path = 'Encrypted', output = 'Decrypted.jpg'):
  """
  Function to Decrypt a Triple DES Encrpyted File.

  Parameters :  path, key, output;

  Key  : Takes a Key for the Decryption Process.
  Path : Takes Absolute or Relative Path of File as Input.
  Output : Takes Absolute or Relative Path of File as Output.

  Returns : An Decrypted File.
  """
  with open(path, 'rb') as file1:
    ciphertext = file1.read()
    cipher_decrypt = triple_des(key, CBC, "\0\0\0\0\0\0\0\0", pad=None, padmode= PAD_PKCS5)
    plaintext = cipher_decrypt.decrypt(ciphertext)
    with open(output, 'wb') as file2:
      file2.write(plaintext)
  print("Decryption Complete.")

# %% [markdown]
# # Demonstration

# %% [markdown]
# ## Loading Images

# %% [markdown]
# ##Testing 1
# ##Example 1

# %%
# !rm *.*
# !wget https://image.freepik.com/free-vector/rose-bouquet-illustration_1284-20872.jpg
# !mv *.jpg 1.jpg
# Out:
# --2021-09-14 07:44:20--  https://image.freepik.com/free-vector/rose-bouquet-illustration_1284-20872.jpg
# Resolving image.freepik.com (image.freepik.com)... 104.122.43.56, 2600:1407:3c00:1088::30ec, 2600:1407:3c00:10a1::30ec
# Connecting to image.freepik.com (image.freepik.com)|104.122.43.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78106 (76K) [image/jpeg]
# Saving to: ‘rose-bouquet-illustration_1284-20872.jpg’
#
# rose-bouquet-illust 100%[===================>]  76.28K  --.-KB/s    in 0.1s
#
# 2021-09-14 07:44:20 (764 KB/s) - ‘rose-bouquet-illustration_1284-20872.jpg’ saved [78106/78106]

# %% [markdown]
# ## Credentials

# %%
key = 'Sixteen byte key'
img = "1.jpg"
enc = "enc.jpg"
out = "output.jpg"

# %% [markdown]
# ## Encryption

# %%
imgdis(img)
encrypt(key, img, enc)
# Out:
# Encryption Complete.

# %%
## Error in Reading Encyrpted File
try:
  imgdis(enc)
except :
  print("UnidentifiedImageError : Cannot identify Image File.")
# Out:
# UnidentifiedImageError : Cannot identify Image File.

# %% [markdown]
# ## Decryption

# %%
decrypt(key, enc, out)
imgdis(out)
# Out:
# Decryption Complete.

# %% [markdown]
# ##Testing 2
# ##Example 2

# %%
# !rm *.*
# !wget https://www.jagranimages.com/images/newimg/10082020/10_08_2020-indian_army_20611556.jpg
# !mv *.jpg 1.jpg
# Out:
# --2021-09-14 07:45:03--  https://www.jagranimages.com/images/newimg/10082020/10_08_2020-indian_army_20611556.jpg
# Resolving www.jagranimages.com (www.jagranimages.com)... 65.8.48.99, 65.8.48.106, 65.8.48.65, ...
# Connecting to www.jagranimages.com (www.jagranimages.com)|65.8.48.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48229 (47K) [image/jpeg]
# Saving to: ‘10_08_2020-indian_army_20611556.jpg’
#
# 10_08_2020-indian_a 100%[===================>]  47.10K  --.-KB/s    in 0.01s
#
# 2021-09-14 07:45:03 (3.44 MB/s) - ‘10_08_2020-indian_army_20611556.jpg’ saved [48229/48229]

# %%
key = 'Sixteen byte key'
img = "1.jpg"
enc = "enc.jpg"
out = "output.jpg"

# %% [markdown]
# ###Encryption

# %%
imgdis(img)
encrypt(key, img, enc)
# Out:
# Encryption Complete.

# %%
## Error in Reading Encyrpted File
try:
  imgdis(enc)
except :
  print("UnidentifiedImageError : Cannot identify Image File.")
# Out:
# UnidentifiedImageError : Cannot identify Image File.

# %% [markdown]
# ###Decryption

# %%
decrypt(key, enc, out)
imgdis(out)
# Out:
# Decryption Complete.
